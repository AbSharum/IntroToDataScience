# %%
import numpy as np
import pandas as pd
import datetime

data = pd.read_csv('phone_data.csv')
data['date'] = pd.to_datetime(data['date'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 830 entries, 0 to 829
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         830 non-null    int64
#  1   date          830 non-null    datetime64[ns]
#  2   duration      830 non-null    float64
#  3   item          830 non-null    object
#  4   month         830 non-null    object
#  5   network       830 non-null    object
#  6   network_type  830 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(4)
# memory usage: 45.5+ KB
# C:\Users\Abxbo\AppData\Local\Temp\ipykernel_10216\3180169084.py:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['date'] = pd.to_datetime(data['date'])

# %%
data.describe()
# Out:
#             index                           date      duration
# count  830.000000                            830    830.000000
# mean   414.500000  2014-12-19 09:03:13.951807232    117.804036
# min      0.000000            2014-01-11 06:58:00      1.000000
# 25%    207.250000            2014-10-25 12:58:00      1.000000
# 50%    414.500000            2014-12-19 13:44:30     24.500000
# 75%    621.750000            2015-02-03 09:30:00     55.000000
# max    829.000000            2015-12-03 06:58:00  10528.000000
# std    239.744656                            NaN    444.129560

# %%
data['network'].unique()
# Out:
# array(['data', 'Vodafone', 'Meteor', 'Tesco', 'Three', 'voicemail',
#        'landline', 'special', 'world'], dtype=object)

# %%
data['item'].unique()
# Out:
# array(['data', 'call', 'sms'], dtype=object)

# %%
data['year'] = data['date'].dt.year
data['duration'][data['year'] == 2015].sum()
# Out:
# 46945.888000000006

# %%
data[data['item'] == 'sms'].groupby('year')['item'].count()
# Out:
# year
# 2014    196
# 2015     96
# Name: item, dtype: int64

# %%
data.groupby('network')['duration'].sum()
# Out:
# network
# Meteor        7233.00
# Tesco        13841.00
# Three        36551.00
# Vodafone     14770.00
# data          5164.35
# landline     18433.00
# special          3.00
# voicemail     1775.00
# world            7.00
# Name: duration, dtype: float64

# %%
data[data['item'] == 'data'][data['month'] == '2015-03'].groupby('month')['duration'].sum()
# Out:
# C:\Users\Abxbo\AppData\Local\Temp\ipykernel_10216\1517468493.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data[data['item'] == 'data'][data['month'] == '2015-03'].groupby('month')['duration'].sum()
# month
# 2015-03    998.441
# Name: duration, dtype: float64
